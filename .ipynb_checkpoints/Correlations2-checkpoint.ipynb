# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("frb_01_overall_new.csv")
df.head()
# Out:
#     OPEID                                   School Name  Risk Factor  \
# 0  100200  ALABAMA AGRICULTURAL & MECHANICAL UNIVERSITY       0.3750
# 1  100300                           FAULKNER UNIVERSITY       0.5625
# 2  100400                      UNIVERSITY OF MONTEVALLO       0.6250
# 3  100500                      ALABAMA STATE UNIVERSITY       0.3750
# 4  100700             CENTRAL ALABAMA COMMUNITY COLLEGE       0.5625
#
#   Borrowing Risk ELIGIND CERTCD                 T & C  Ethnic Class  \
# 0      Less Risk       Y      C  Public 4 Yrs or More             2
# 1  Moderate Risk       Y      C     PNP 4 Yrs or More             5
# 2      More Risk       Y      C  Public 4 Yrs or More             5
# 3      Less Risk       Y      P  Public 4 Yrs or More             2
# 4  Moderate Risk       Y      P      Public 2 - 3 Yrs             5
#
#    % Completions Any School  % Completions Same School  \
# 0                      0.44                       0.39
# ...

# %%
corr = df['Risk Factor'].corr(df['% Completions Any School'])
corr
# Out:
# 0.05159150446799704

# %%
df1 = df[['Risk Factor','% Completions Any School']]

# %%
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "regression")))

# %%
sns.regplot(x="Risk Factor", 
            y="% Completions Any School", 
            data=df1).set_title('Risk Factor vs % Completions Any School');

# %%
corr = df['Risk Factor'].corr(df['% Completions Same School'])
corr
# Out:
# -0.031297374115437149

# %%
df2 = df[['Risk Factor','% Completions Same School']]
sns.regplot(x="Risk Factor", 
            y='% Completions Same School', 
            data=df2).set_title('Risk Factor vs % Completions Same School');

# %%
corr = df['Risk Factor'].corr(df['% Independent Borrower Count'])
corr
# Out:
# -0.057238831074319138

# %%
df3 = df[['Risk Factor','% Independent Borrower Count']]
sns.regplot(x="Risk Factor", 
            y='% Independent Borrower Count', 
            data=df3).set_title('Risk Factor vs % Independent Borrower Count');

# %%
corr = df['Risk Factor'].corr(df['% Dependent Borrower Count'])
corr
# Out:
# 0.20695348564619415

# %%
df4 = df[['Risk Factor','% Dependent Borrower Count']]
sns.regplot(x="Risk Factor", 
            y='% Dependent Borrower Count', 
            data=df4).set_title('Risk Factor vs % Dependent Borrower Count');

# %%
corr = df['Risk Factor'].corr(df['Median Independent Student AGI'])
corr
# Out:
# 0.1710684946947936

# %%
df5 = df[['Risk Factor','Median Independent Student AGI']]
sns.regplot(x="Risk Factor", 
            y='Median Independent Student AGI', 
            data=df5).set_title('Risk Factor vs Median Independent Student AGI');

# %%
corr = df['Risk Factor'].corr(df['% Independent Borrowers with AGI < $30K'])
corr
# Out:
# -0.07773226920022773

# %%
df6 = df[['Risk Factor','% Independent Borrowers with AGI < $30K']]
sns.regplot(x="Risk Factor", 
            y='% Independent Borrowers with AGI < $30K', 
            data=df6).set_title('Risk Factor vs % Independent Borrowers with AGI < $30K');

# %%
corr = df['Risk Factor'].corr(df['Median Dependent Parent AGI'])
corr
# Out:
# 0.39034128759108833

# %%
df7 = df[['Risk Factor','Median Dependent Parent AGI']]
sns.regplot(x="Risk Factor", 
            y='Median Dependent Parent AGI', 
            data=df7).set_title('Risk Factor vs Median Dependent Parent AGI');

# %%
corr = df['Risk Factor'].corr(df['% Dependent Borrowers with AGI < $30K'])
corr
# Out:
# -0.24847671596937343

# %%
df8 = df[['Risk Factor','% Dependent Borrowers with AGI < $30K']]
sns.regplot(x="Risk Factor", 
            y='% Dependent Borrowers with AGI < $30K', 
            data=df8).set_title('Risk Factor vs % Dependent Borrowers with AGI < $30K');

# %%
corr = df['Risk Factor'].corr(df['% Borrowers with a Pell Grant'])
corr
# Out:
# -0.018459013984696852

# %%
df9 = df[['Risk Factor','% Borrowers with a Pell Grant']]
sns.regplot(x="Risk Factor", 
            y='% Borrowers with a Pell Grant', 
            data=df9).set_title('Risk Factor vs % Borrowers with a Pell Grant');

# %%
corr = df['Risk Factor'].corr(df['% Borrowers without a Pell Grant'])
corr
# Out:
# 0.47378549654804358

# %%
df9 = df[['Risk Factor','% Borrowers without a Pell Grant']]
sns.regplot(x="Risk Factor", 
            y='% Borrowers without a Pell Grant', 
            data=df9).set_title('Risk Factor vs % Borrowers without a Pell Grant');

# %%
corr = df['Risk Factor'].corr(df['Median Age of Dependent Borrowers at Maturity'])
corr
# Out:
# 0.051547139849865996

# %%
df10 = df[['Risk Factor','Median Age of Dependent Borrowers at Maturity']]
sns.regplot(x="Risk Factor", 
            y='Median Age of Dependent Borrowers at Maturity', 
            data=df10).set_title('Risk Factor vs Median Age of Dependent Borrowers at Maturity');

# %%
corr = df['Risk Factor'].corr(df['Median Age of Independent Borrowers at Maturity'])
corr
# Out:
# -0.064680415488818269

# %%
df11 = df[['Risk Factor','Median Age of Independent Borrowers at Maturity']]
sns.regplot(x="Risk Factor", 
            y='Median Age of Independent Borrowers at Maturity', 
            data=df11).set_title('Risk Factor vs Median Age of Independent Borrowers at Maturity');

# %%
corr = df['Risk Factor'].corr(df['Mean Balance'])
corr
# Out:
# 0.22742335279013975

# %%
df12 = df[['Risk Factor','Mean Balance']]
sns.regplot(x="Risk Factor", 
            y='Mean Balance', 
            data=df12).set_title('Risk Factor vs Mean Balance');

# %%
corr = df['Risk Factor'].corr(df['Median Balance'])
corr
# Out:
# 0.19581748709985694

# %%
df13 = df[['Risk Factor','Median Balance']]
sns.regplot(x="Risk Factor", 
            y='Median Balance', 
            data=df13).set_title('Risk Factor vs Median Balance');
